# %%
from shapeGMMTorch import torch_sgmm
from shapeGMMTorch import scripts

import MDAnalysis as md
import torch
from glob import glob
import numpy as np
import os


apo_residues = "882 to 1061"
holo_residues = "981 to 1131"

apo_eq_traj = "/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/setup/eq/md_v.xtc"
#apo_eq_gro = "/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/setup/eq/npt.gro"
apo_eq_top = "apo_actin_vinculin_labeled.pdb"

holo_eq_traj = "/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/setup/eq/md_v.xtc"
#holo_eq_gro = "/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/setup/eq/npt.gro"
holo_eq_top = "holo_actin_vinculin_labeled.pdb"

# %%
def load_trajectory(trj,top,atoms="name CA", residues="", write_frame=None, write_prefix=None, segment=""):
    coord = md.Universe(top,trj)

    print("Number of atoms in trajectory:", coord.atoms.n_atoms)
    print("Number of frames in trajectory:", coord.trajectory.n_frames)
    # make atom selection
    if len(residues)>0:
        residue_string = f"and resnum {residues}" 
    else:
        residue_string = ""
    if len(atoms)>0:
        atom_string = f"and {atoms}" 
    else:
        atom_string = ""

    if len(segment)>0:
        segment_string = f"and segid {segment}" 
    else:
        segment_string = ""
    atomSel = coord.select_atoms(f'protein {atom_string} {residue_string} {segment_string}')
    print("Number of atoms in selection:", atomSel.n_atoms)
    print(atomSel)

    if write_frame is not None and write_prefix is not None:
        atomSel.write(f"{write_prefix}_frame{write_frame}.pdb",frames=coord.trajectory[[write_frame]])
    
    # create traj data of selection
    traj_data = np.empty((coord.trajectory.n_frames,atomSel.n_atoms,3),dtype=float)
    #loop traj
    for ts in coord.trajectory:
        traj_data[ts.frame,:] = atomSel.positions
        
    return traj_data

# %%
def get_representative_frames(sgmm, traj_data):
    """
    Write representative frames for each cluster
    This is defined as the frame with the largest LL to each cluster
    """
    # get meta data from inputs
    n_frames = traj_data.shape[0]
    n_atoms = sgmm.n_atoms
    n_clusters = sgmm.n_clusters
    # loop through clusters
    representative_list = []
    cluster_ids = sgmm.predict(traj_data)

    for cluster_id in range(n_clusters):
        indices = np.argwhere(cluster_ids==cluster_id).flatten()
        frameid_max = np.argmax(sgmm.predict_frame_log_likelihood[indices])
        representive_frame_id = indices[frameid_max]
        representative_list.append( (cluster_id, representive_frame_id, sgmm.predict_frame_log_likelihood[indices][frameid_max]) )
    return representative_list

# %%
#apo_trj = load_trajectory(apo_eq_traj,apo_eq_top,residues=apo_residues)
apo_trj = load_trajectory(apo_eq_traj,apo_eq_top,segment="V",atoms='backbone')
# Out:
# Number of atoms in trajectory: 235307
# Number of frames in trajectory: 5001
# Number of atoms in selection: 719
# <AtomGroup [<Atom 29356: N of type N of resname ASP, resid 882 and segid V and altLoc >, <Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29368: C of type C of resname ASP, resid 882 and segid V and altLoc >, ..., <Atom 32186: N of type N of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >]>

# %%
holo_trj = load_trajectory(holo_eq_traj,holo_eq_top,segment="V",atoms='backbone')
# Out:
# Number of atoms in trajectory: 228126
# Number of frames in trajectory: 5001
# Number of atoms in selection: 603
# <AtomGroup [<Atom 29356: N of type N of resname SER, resid 981 and segid V and altLoc >, <Atom 29360: CA of type C of resname SER, resid 981 and segid V and altLoc >, <Atom 29367: C of type C of resname SER, resid 981 and segid V and altLoc >, ..., <Atom 31731: N of type N of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31735: CA of type C of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31743: C of type C of resname PRO, resid 1131 and segid V and altLoc >]>

# %%
# use frame weights to only use last fraction of trajectory
print("DOING APO")
frame_weights_selection = np.ones(len(apo_trj))
frame_weights_selection[:len(frame_weights_selection)//4]=0
apo_align_sgmm = scripts.sgmm_fit_with_attempts(apo_trj, 1, 1, frame_weights=frame_weights_selection, device=torch.device("cuda"))
rep_frames = get_representative_frames(apo_align_sgmm, apo_trj)
print("most representative frames",rep_frames)
#now write this frame
_ = load_trajectory(apo_eq_traj, apo_eq_top, atoms="", write_frame=rep_frames[0][1], write_prefix="representative_frames/apo_eq_trj_clust0rep")

print("DOING HOLO")
frame_weights_selection = np.ones(len(holo_trj))
frame_weights_selection[:len(frame_weights_selection)//4]=0
holo_align_sgmm = scripts.sgmm_fit_with_attempts(holo_trj, 1, 1, frame_weights=frame_weights_selection, device=torch.device("cuda"))
rep_frames = get_representative_frames(holo_align_sgmm, holo_trj)
print("most representative frames",rep_frames)
#now write this frame
_ = load_trajectory(holo_eq_traj, holo_eq_top, atoms="", write_frame=rep_frames[0][1], write_prefix="representative_frames/holo_eq_trj_clust0rep")
# Out:
# DOING APO
# Number of training frames: 5001
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            4267.878           4.370
# most representative frames [(0, 4529, 4508.943567028365)]
# Number of atoms in trajectory: 235307
# Number of frames in trajectory: 5001
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# DOING HOLO
# Number of training frames: 5001
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            3493.373           5.707
# most representative frames [(0, 4885, 3680.264897115196)]
# Number of atoms in trajectory: 228126
# Number of frames in trajectory: 5001
# Number of atoms in selection: 31545
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 31743: C of type C of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31744: OT1 of type O of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31745: OT2 of type O of resname PRO, resid 1131 and segid V and altLoc >]>
# array([[[27.22000122, 20.42000008, 64.02000427],
#         [26.87000084, 19.51000023, 63.67000198],
#         [27.74000168, 20.43000031, 64.91999817],
#         ...,
#         [76.32000732, 30.79000282, 36.79000092],
#         [76.9200058 , 31.22000122, 37.86000061],
#         [75.07000732, 30.69000244, 36.74000168]],
#
#        [[27.47000122, 19.72999954, 64.29000092],
#         [26.65000153, 19.27000046, 63.85000229],
#         [28.10000229, 19.04000092, 64.73000336],
#         ...,
#         [74.95000458, 31.78000259, 33.31000137],
#         [73.76000214, 31.90000153, 33.66000366],
#         [75.77000427, 32.67000198, 33.68000412]],
#
#        [[27.01000214, 20.28000069, 63.80000305],
#         [26.7100029 , 19.34000206, 63.4600029 ],
#         [27.35000229, 20.26000023, 64.77999878],
#         ...,
#         [76.70000458, 31.15000153, 34.15000153],
#         [76.30000305, 32.29000092, 33.75000381],
#         [76.27999878, 30.63000107, 35.25      ]],
#
#        ...,
#
#        [[26.83000183, 20.09000015, 63.81000519],
#         [27.2100029 , 20.34000206, 64.75      ],
#         [25.84000015, 20.41000175, 63.77000427],
#         ...,
#         [70.65000916, 29.42000198, 38.94000244],
#         [69.95000458, 29.48000145, 39.99000168],
#         [70.59000397, 28.47999954, 38.13999939]],
#
#        [[27.32999992, 20.47000122, 64.14000702],
#         [26.88000107, 19.57999992, 63.85000229],
#         [28.13000107, 20.13000107, 64.70999908],
#         ...,
#         [70.34000397, 28.11000061, 40.08000183],
#         [69.84000397, 28.47000122, 41.20000458],
#         [70.01000214, 27.04000282, 39.55000305]],
#
#        [[27.08000183, 20.86000252, 63.36000443],
#         [26.17000198, 21.37000084, 63.27999878],
#         [26.95000076, 19.84000015, 63.24000549],
#         ...,
#         [70.33000183, 28.73000145, 41.01000214],
#         [70.18000031, 28.09000015, 42.05000305],
#         [69.70999908, 28.47999954, 39.90000153]]])

# %%
## Now get data with force
kBT=0.593

fes_apo_top = "apo_actin_vinculin_fes_labeled.pdb"
force_dirs = glob("/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_*20.0/*")
for force_dir in force_dirs:
    label = os.path.basename(os.path.dirname(force_dir))+'_seed'+os.path.basename(force_dir)
    xtc_file = glob(os.path.join(force_dir,"*full*.xtc"))
    if not xtc_file: 
        print("Skipping",force_dir)
    opes_file = glob(f"{force_dir}/*opes*.out")
    if len(opes_file)>1:
        print("Error, more than one opes file in",force_dir)
    else:
        opes_file = opes_file[0]
    opes_data = np.loadtxt(opes_file)
    #check for repeat rows
    repeat_lines = np.where( opes_data[1:,0]-opes_data[:-1,0] ==0 )[0] 
    opes_data = np.delete(opes_data, repeat_lines,axis=0)

    bias_trj = opes_data[::20,1]
    bias_trj-=bias_trj[0]
    
    frame_weights = np.exp(bias_trj/kBT)
    print(frame_weights.min())
    print(frame_weights.max())

    print(f"...Analyzing {xtc_file}")
    biased_trj = load_trajectory(xtc_file,fes_apo_top,segment="V",atoms='name CA')
    print(biased_trj.shape)
    print(frame_weights.shape)
    try:
        apo_align_sgmm = scripts.sgmm_fit_with_attempts(biased_trj, 1, 1, frame_weights=frame_weights, device=torch.device("cuda"),dtype=torch.float64)
        
        rep_frames = get_representative_frames(apo_align_sgmm, biased_trj)
        print(f"most representative frames for {force_dir}:",rep_frames)
    #now write this frame
        _ = load_trajectory(xtc_file, fes_apo_top, atoms="", write_frame=rep_frames[0][1], write_prefix=f"representative_frames/fes/apo/{label}_rep")
    except RuntimeError as e:
        print("Error processing")
        print(e)
# Out:
# 1.0
# 8749509445648457.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/7/7_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1             969.036           2.815
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/7: [(0, 315, 1217.591590125819)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 5.335209886569078e+16
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/6/6_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1495.305           2.771
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/6: [(0, 2421, 1762.6872886680676)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 6490819970851897.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/3/3_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            2126.996           2.940
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/3: [(0, 251, 2394.614717275059)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 4261774668682811.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/11/11_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2471
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2471, 180, 3)
# (2484,)
# Number of training frames: 2471
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
# Error processing
# The size of tensor a (2484) must match the size of tensor b (2471) at non-singleton dimension 0
# 1.0
# 2250474255883465.2
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/19/19_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            3119.483           2.825
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/19: [(0, 39, 3382.0370125540535)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 7792443367929069.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/14/14_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1159.524           2.824
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/14: [(0, 1071, 1421.3031957094854)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 8327746685888191.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/17/17_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1179.875           2.846
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/17: [(0, 1071, 1417.495447667939)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 1.4103232741300628e+16
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/5/5_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1624.765           2.798
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/5: [(0, 581, 1889.8503737859512)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 350268722290545.4
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/2/2_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            2122.016           2.949
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/2: [(0, 118, 2382.0900121771947)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 4622630468905944.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/4/4_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1140.915           2.789
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/4: [(0, 2264, 1401.999386303305)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 9104848546608868.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/1/1_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            2507.594           2.910
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/1: [(0, 107, 2775.0389773317975)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 9240549424324950.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/13/13_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1395.601           2.790
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/13: [(0, 647, 1653.1777558993529)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 309652088821154.3
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/16/16_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            2873.391           2.844
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/16: [(0, 113, 3140.3003598089063)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 4.9585200281626024e+16
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/20/20_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1072.571           2.855
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/20: [(0, 1573, 1335.5539770311116)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 7586256661374985.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/9/9_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1             810.678           2.789
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/9: [(0, 391, 1048.086058251686)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 1851075102487695.8
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/12/12_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1748.396           2.867
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/12: [(0, 153, 2004.5925365763403)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 3694147251656421.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/15/15_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1607.371           2.846
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/15: [(0, 234, 1865.5603022996254)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 7.096593664263916e+16
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/10/10_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            2103.113           2.811
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/10: [(0, 958, 2369.0020112382076)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 2850828851526234.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/8/8_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1139.926           2.984
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/8: [(0, 1537, 1386.853169602254)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 1223294198417628.2
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/18/18_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            2170.112           2.947
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_20.0/18: [(0, 146, 2433.6197830035853)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 5372107192598570.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/7/7_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1989.545           2.859
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/7: [(0, 695, 2253.704146587701)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 4640164152791862.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/6/6_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            2160.157           2.786
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/6: [(0, 113, 2422.534835318303)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 1.1094426103645668e+16
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/3/3_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1709.348           2.815
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/3: [(0, 309, 1970.6474679742382)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 4254902444207194.5
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/11/11_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2513,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
# Error processing
# The size of tensor a (2513) must match the size of tensor b (2501) at non-singleton dimension 0
# 1.0
# 8641702906476919.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/19/19_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            2316.779           2.934
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/19: [(0, 327, 2579.269146619479)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 6623797189045822.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/14/14_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2514,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
# Error processing
# The size of tensor a (2514) must match the size of tensor b (2501) at non-singleton dimension 0
# 1.0
# 4274535939706383.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/17/17_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1309.516           2.815
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/17: [(0, 18, 1562.6212850553802)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 4.438597035259051e+16
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/5/5_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2514,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
# Error processing
# The size of tensor a (2514) must match the size of tensor b (2501) at non-singleton dimension 0
# 1.0
# 1912747398661703.5
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/2/2_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# ...
# Number of frames in trajectory: 2486
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2486, 180, 3)
# (2486,)
# Number of training frames: 2486
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            2141.086           2.753
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/13: [(0, 116, 2401.651877651878)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2486
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 3565122125136175.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/16/16_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1372.221           2.870
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/16: [(0, 1089, 1624.5608192806972)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 1.2604556098371404e+16
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/20/20_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1234.673           2.809
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/20: [(0, 369, 1491.3565568225551)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 2327701448652366.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/9/9_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            2610.029           2.807
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/9: [(0, 69, 2874.3636529377864)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 2484170034252581.5
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/12/12_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1344.578           2.880
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/12: [(0, 711, 1586.9564963053774)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 1624234164451306.2
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/15/15_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1532.878           2.805
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/15: [(0, 343, 1774.9359661737963)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 2.5526902089523788e+16
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/10/10_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1             852.974           2.800
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/10: [(0, 1825, 1095.1784041179296)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 5.411641728876023e+16
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/8/8_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1797.514           2.780
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/8: [(0, 241, 2063.9068837606596)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>
# 1.0
# 5819907181104790.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/18/18_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid V and altLoc >, <Atom 29372: CA of type C of resname GLU, resid 883 and segid V and altLoc >, <Atom 29387: CA of type C of resname GLU, resid 884 and segid V and altLoc >, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid V and altLoc >, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid V and altLoc >, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid V and altLoc >]>
# (2501, 180, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1549.028           2.816
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_opes_pullProj_free_gpu_pn_-20.0/18: [(0, 118, 1806.2652971058922)]
# Number of atoms in trajectory: 290139
# Number of frames in trajectory: 2501
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid V and altLoc >, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid V and altLoc >]>

# %%
kBT=0.593

fes_holo_top = "holo_actin_vinculin_fes_labeled.pdb"
force_dirs = glob("/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_*20.0//*")
for force_dir in reversed(force_dirs):
    label = os.path.basename(os.path.dirname(force_dir))+'_seed'+os.path.basename(force_dir)
    xtc_file = glob(os.path.join(force_dir,"*full*.xtc"))
    if not xtc_file: 
        print("Skipping",force_dir)
    opes_file = glob(f"{force_dir}/*opes*.out")
    if len(opes_file)>1:
        print("Error, more than one opes file in",force_dir)
    else:
        opes_file = opes_file[0]
    opes_data = np.loadtxt(opes_file)
    #check for repeat rows
    repeat_lines = np.where( opes_data[1:,0]-opes_data[:-1,0] ==0 )[0] 
    opes_data = np.delete(opes_data, repeat_lines,axis=0)

    bias_trj = opes_data[::20,1]
    bias_trj-=bias_trj[0]
    ##max out bias to avoid numerical errors
    ##bias_trj[bias_trj>20]=20

    
    frame_weights = np.exp(bias_trj/kBT)
    print(frame_weights.min())
    print(frame_weights.max())

    print(f"...Analyzing {xtc_file}")
    biased_trj = load_trajectory(xtc_file,fes_holo_top,segment="V",atoms='name CA')
    print(biased_trj.shape)
    print(frame_weights.shape)
    try:
        holo_align_sgmm = scripts.sgmm_fit_with_attempts(biased_trj, 1, 1, frame_weights=frame_weights, device=torch.device("cuda"),dtype=torch.float64)
        
        rep_frames = get_representative_frames(holo_align_sgmm, biased_trj)
        print(f"most representative frames for {force_dir}:",rep_frames)
    #now write this frame
        _ = load_trajectory(xtc_file, fes_holo_top, atoms="", write_frame=rep_frames[0][1], write_prefix=f"representative_frames/fes/holo/{label}_rep")
    except RuntimeError as e:
        print("Error processing")
        print(e)
# Out:
# 1.0
# 1.4040774978473268e+16
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/18/18_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 151
# <AtomGroup [<Atom 29360: CA of type C of resname SER, resid 981 and segid V and altLoc >, <Atom 29371: CA of type C of resname SER, resid 982 and segid V and altLoc >, <Atom 29382: CA of type C of resname LYS, resid 983 and segid V and altLoc >, ..., <Atom 31697: CA of type C of resname LYS, resid 1129 and segid V and altLoc >, <Atom 31719: CA of type C of resname THR, resid 1130 and segid V and altLoc >, <Atom 31735: CA of type C of resname PRO, resid 1131 and segid V and altLoc >]>
# (2501, 151, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1250.604           5.607
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/18: [(0, 247, 1462.2551374768234)]
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 31545
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 31743: C of type C of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31744: OT1 of type O of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31745: OT2 of type O of resname PRO, resid 1131 and segid V and altLoc >]>
# 1.0
# 2130162589655497.8
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/8/8_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 151
# <AtomGroup [<Atom 29360: CA of type C of resname SER, resid 981 and segid V and altLoc >, <Atom 29371: CA of type C of resname SER, resid 982 and segid V and altLoc >, <Atom 29382: CA of type C of resname LYS, resid 983 and segid V and altLoc >, ..., <Atom 31697: CA of type C of resname LYS, resid 1129 and segid V and altLoc >, <Atom 31719: CA of type C of resname THR, resid 1130 and segid V and altLoc >, <Atom 31735: CA of type C of resname PRO, resid 1131 and segid V and altLoc >]>
# (2501, 151, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1485.469           4.111
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/8: [(0, 17, 1704.3459117486739)]
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 31545
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 31743: C of type C of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31744: OT1 of type O of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31745: OT2 of type O of resname PRO, resid 1131 and segid V and altLoc >]>
# 1.0
# 2294531843045426.5
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/10/10_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 151
# <AtomGroup [<Atom 29360: CA of type C of resname SER, resid 981 and segid V and altLoc >, <Atom 29371: CA of type C of resname SER, resid 982 and segid V and altLoc >, <Atom 29382: CA of type C of resname LYS, resid 983 and segid V and altLoc >, ..., <Atom 31697: CA of type C of resname LYS, resid 1129 and segid V and altLoc >, <Atom 31719: CA of type C of resname THR, resid 1130 and segid V and altLoc >, <Atom 31735: CA of type C of resname PRO, resid 1131 and segid V and altLoc >]>
# (2501, 151, 3)
# (2512,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
# Error processing
# The size of tensor a (2512) must match the size of tensor b (2501) at non-singleton dimension 0
# 1.0
# 1.0094178278679624e+16
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/15/15_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 151
# <AtomGroup [<Atom 29360: CA of type C of resname SER, resid 981 and segid V and altLoc >, <Atom 29371: CA of type C of resname SER, resid 982 and segid V and altLoc >, <Atom 29382: CA of type C of resname LYS, resid 983 and segid V and altLoc >, ..., <Atom 31697: CA of type C of resname LYS, resid 1129 and segid V and altLoc >, <Atom 31719: CA of type C of resname THR, resid 1130 and segid V and altLoc >, <Atom 31735: CA of type C of resname PRO, resid 1131 and segid V and altLoc >]>
# (2501, 151, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1             698.817           4.014
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/15: [(0, 1786, 870.6761657257367)]
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 31545
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 31743: C of type C of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31744: OT1 of type O of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31745: OT2 of type O of resname PRO, resid 1131 and segid V and altLoc >]>
# 1.0
# 1236019894778410.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/12/12_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 151
# <AtomGroup [<Atom 29360: CA of type C of resname SER, resid 981 and segid V and altLoc >, <Atom 29371: CA of type C of resname SER, resid 982 and segid V and altLoc >, <Atom 29382: CA of type C of resname LYS, resid 983 and segid V and altLoc >, ..., <Atom 31697: CA of type C of resname LYS, resid 1129 and segid V and altLoc >, <Atom 31719: CA of type C of resname THR, resid 1130 and segid V and altLoc >, <Atom 31735: CA of type C of resname PRO, resid 1131 and segid V and altLoc >]>
# (2501, 151, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1319.369           4.138
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/12: [(0, 170, 1529.551266919364)]
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 31545
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 31743: C of type C of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31744: OT1 of type O of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31745: OT2 of type O of resname PRO, resid 1131 and segid V and altLoc >]>
# 1.0
# 5537084642780418.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/9/9_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 151
# <AtomGroup [<Atom 29360: CA of type C of resname SER, resid 981 and segid V and altLoc >, <Atom 29371: CA of type C of resname SER, resid 982 and segid V and altLoc >, <Atom 29382: CA of type C of resname LYS, resid 983 and segid V and altLoc >, ..., <Atom 31697: CA of type C of resname LYS, resid 1129 and segid V and altLoc >, <Atom 31719: CA of type C of resname THR, resid 1130 and segid V and altLoc >, <Atom 31735: CA of type C of resname PRO, resid 1131 and segid V and altLoc >]>
# (2501, 151, 3)
# (2512,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
# Error processing
# The size of tensor a (2512) must match the size of tensor b (2501) at non-singleton dimension 0
# 1.0
# 1.3051787829258564e+16
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/20/20_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 151
# <AtomGroup [<Atom 29360: CA of type C of resname SER, resid 981 and segid V and altLoc >, <Atom 29371: CA of type C of resname SER, resid 982 and segid V and altLoc >, <Atom 29382: CA of type C of resname LYS, resid 983 and segid V and altLoc >, ..., <Atom 31697: CA of type C of resname LYS, resid 1129 and segid V and altLoc >, <Atom 31719: CA of type C of resname THR, resid 1130 and segid V and altLoc >, <Atom 31735: CA of type C of resname PRO, resid 1131 and segid V and altLoc >]>
# (2501, 151, 3)
# (2511,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
# Error processing
# The size of tensor a (2511) must match the size of tensor b (2501) at non-singleton dimension 0
# 1.0
# 1060677929035744.2
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/16/16_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 151
# <AtomGroup [<Atom 29360: CA of type C of resname SER, resid 981 and segid V and altLoc >, <Atom 29371: CA of type C of resname SER, resid 982 and segid V and altLoc >, <Atom 29382: CA of type C of resname LYS, resid 983 and segid V and altLoc >, ..., <Atom 31697: CA of type C of resname LYS, resid 1129 and segid V and altLoc >, <Atom 31719: CA of type C of resname THR, resid 1130 and segid V and altLoc >, <Atom 31735: CA of type C of resname PRO, resid 1131 and segid V and altLoc >]>
# (2501, 151, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1218.223           4.076
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/16: [(0, 224, 1432.5858144204792)]
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 31545
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 31743: C of type C of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31744: OT1 of type O of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31745: OT2 of type O of resname PRO, resid 1131 and segid V and altLoc >]>
# 1.0
# 1.364484623347235e+16
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/13/13_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 151
# <AtomGroup [<Atom 29360: CA of type C of resname SER, resid 981 and segid V and altLoc >, <Atom 29371: CA of type C of resname SER, resid 982 and segid V and altLoc >, <Atom 29382: CA of type C of resname LYS, resid 983 and segid V and altLoc >, ..., <Atom 31697: CA of type C of resname LYS, resid 1129 and segid V and altLoc >, <Atom 31719: CA of type C of resname THR, resid 1130 and segid V and altLoc >, <Atom 31735: CA of type C of resname PRO, resid 1131 and segid V and altLoc >]>
# (2501, 151, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1257.540           3.919
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/13: [(0, 806, 1478.9282010746806)]
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 31545
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 31743: C of type C of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31744: OT1 of type O of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31745: OT2 of type O of resname PRO, resid 1131 and segid V and altLoc >]>
# 1.0
# 9182592833251474.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/1/1_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 151
# <AtomGroup [<Atom 29360: CA of type C of resname SER, resid 981 and segid V and altLoc >, <Atom 29371: CA of type C of resname SER, resid 982 and segid V and altLoc >, <Atom 29382: CA of type C of resname LYS, resid 983 and segid V and altLoc >, ..., <Atom 31697: CA of type C of resname LYS, resid 1129 and segid V and altLoc >, <Atom 31719: CA of type C of resname THR, resid 1130 and segid V and altLoc >, <Atom 31735: CA of type C of resname PRO, resid 1131 and segid V and altLoc >]>
# (2501, 151, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            2492.734           4.236
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/1: [(0, 150, 2712.8253795421624)]
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 31545
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 31743: C of type C of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31744: OT1 of type O of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31745: OT2 of type O of resname PRO, resid 1131 and segid V and altLoc >]>
# 1.0
# 2.0085489429855892e+16
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/4/4_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2455
# Number of atoms in selection: 151
# <AtomGroup [<Atom 29360: CA of type C of resname SER, resid 981 and segid V and altLoc >, <Atom 29371: CA of type C of resname SER, resid 982 and segid V and altLoc >, <Atom 29382: CA of type C of resname LYS, resid 983 and segid V and altLoc >, ..., <Atom 31697: CA of type C of resname LYS, resid 1129 and segid V and altLoc >, <Atom 31719: CA of type C of resname THR, resid 1130 and segid V and altLoc >, <Atom 31735: CA of type C of resname PRO, resid 1131 and segid V and altLoc >]>
# (2455, 151, 3)
# (2466,)
# Number of training frames: 2455
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
# Error processing
# The size of tensor a (2466) must match the size of tensor b (2455) at non-singleton dimension 0
# 1.0
# 9144116072605000.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/2/2_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 151
# <AtomGroup [<Atom 29360: CA of type C of resname SER, resid 981 and segid V and altLoc >, <Atom 29371: CA of type C of resname SER, resid 982 and segid V and altLoc >, <Atom 29382: CA of type C of resname LYS, resid 983 and segid V and altLoc >, ..., <Atom 31697: CA of type C of resname LYS, resid 1129 and segid V and altLoc >, <Atom 31719: CA of type C of resname THR, resid 1130 and segid V and altLoc >, <Atom 31735: CA of type C of resname PRO, resid 1131 and segid V and altLoc >]>
# (2501, 151, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1377.554           4.030
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/2: [(0, 147, 1595.131966993136)]
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 31545
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 31743: C of type C of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31744: OT1 of type O of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31745: OT2 of type O of resname PRO, resid 1131 and segid V and altLoc >]>
# 1.0
# 2.4819425689863996e+16
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/5/5_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 151
# <AtomGroup [<Atom 29360: CA of type C of resname SER, resid 981 and segid V and altLoc >, <Atom 29371: CA of type C of resname SER, resid 982 and segid V and altLoc >, <Atom 29382: CA of type C of resname LYS, resid 983 and segid V and altLoc >, ..., <Atom 31697: CA of type C of resname LYS, resid 1129 and segid V and altLoc >, <Atom 31719: CA of type C of resname THR, resid 1130 and segid V and altLoc >, <Atom 31735: CA of type C of resname PRO, resid 1131 and segid V and altLoc >]>
# (2501, 151, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1260.080           3.969
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/5: [(0, 235, 1476.6086439792643)]
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 31545
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 31743: C of type C of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31744: OT1 of type O of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31745: OT2 of type O of resname PRO, resid 1131 and segid V and altLoc >]>
# 1.0
# 5870166302037710.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/17/17_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 151
# <AtomGroup [<Atom 29360: CA of type C of resname SER, resid 981 and segid V and altLoc >, <Atom 29371: CA of type C of resname SER, resid 982 and segid V and altLoc >, <Atom 29382: CA of type C of resname LYS, resid 983 and segid V and altLoc >, ..., <Atom 31697: CA of type C of resname LYS, resid 1129 and segid V and altLoc >, <Atom 31719: CA of type C of resname THR, resid 1130 and segid V and altLoc >, <Atom 31735: CA of type C of resname PRO, resid 1131 and segid V and altLoc >]>
# (2501, 151, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1389.497           4.059
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/17: [(0, 471, 1610.8634228609587)]
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 31545
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 31743: C of type C of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31744: OT1 of type O of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31745: OT2 of type O of resname PRO, resid 1131 and segid V and altLoc >]>
# 1.0
# 4021989677425721.5
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/14/14_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 151
# <AtomGroup [<Atom 29360: CA of type C of resname SER, resid 981 and segid V and altLoc >, <Atom 29371: CA of type C of resname SER, resid 982 and segid V and altLoc >, <Atom 29382: CA of type C of resname LYS, resid 983 and segid V and altLoc >, ..., <Atom 31697: CA of type C of resname LYS, resid 1129 and segid V and altLoc >, <Atom 31719: CA of type C of resname THR, resid 1130 and segid V and altLoc >, <Atom 31735: CA of type C of resname PRO, resid 1131 and segid V and altLoc >]>
# (2501, 151, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1137.488           4.276
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/14: [(0, 480, 1359.7012372837976)]
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 31545
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 31743: C of type C of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31744: OT1 of type O of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31745: OT2 of type O of resname PRO, resid 1131 and segid V and altLoc >]>
# 1.0
# 1.4301415413612624e+16
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/19/19_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 151
# <AtomGroup [<Atom 29360: CA of type C of resname SER, resid 981 and segid V and altLoc >, <Atom 29371: CA of type C of resname SER, resid 982 and segid V and altLoc >, <Atom 29382: CA of type C of resname LYS, resid 983 and segid V and altLoc >, ..., <Atom 31697: CA of type C of resname LYS, resid 1129 and segid V and altLoc >, <Atom 31719: CA of type C of resname THR, resid 1130 and segid V and altLoc >, <Atom 31735: CA of type C of resname PRO, resid 1131 and segid V and altLoc >]>
# (2501, 151, 3)
# (2511,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
# Error processing
# The size of tensor a (2511) must match the size of tensor b (2501) at non-singleton dimension 0
# 1.0
# 5875960132903786.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/11/11_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 151
# <AtomGroup [<Atom 29360: CA of type C of resname SER, resid 981 and segid V and altLoc >, <Atom 29371: CA of type C of resname SER, resid 982 and segid V and altLoc >, <Atom 29382: CA of type C of resname LYS, resid 983 and segid V and altLoc >, ..., <Atom 31697: CA of type C of resname LYS, resid 1129 and segid V and altLoc >, <Atom 31719: CA of type C of resname THR, resid 1130 and segid V and altLoc >, <Atom 31735: CA of type C of resname PRO, resid 1131 and segid V and altLoc >]>
# (2501, 151, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1595.481           3.909
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/11: [(0, 144, 1816.0606865539019)]
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 31545
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 31743: C of type C of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31744: OT1 of type O of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31745: OT2 of type O of resname PRO, resid 1131 and segid V and altLoc >]>
# 1.0
# 2918279594740599.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/3/3_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 151
# <AtomGroup [<Atom 29360: CA of type C of resname SER, resid 981 and segid V and altLoc >, <Atom 29371: CA of type C of resname SER, resid 982 and segid V and altLoc >, <Atom 29382: CA of type C of resname LYS, resid 983 and segid V and altLoc >, ..., <Atom 31697: CA of type C of resname LYS, resid 1129 and segid V and altLoc >, <Atom 31719: CA of type C of resname THR, resid 1130 and segid V and altLoc >, <Atom 31735: CA of type C of resname PRO, resid 1131 and segid V and altLoc >]>
# (2501, 151, 3)
# (2512,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
# Error processing
# The size of tensor a (2512) must match the size of tensor b (2501) at non-singleton dimension 0
# 1.0
# 1.838531855526144e+16
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/6/6_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 151
# <AtomGroup [<Atom 29360: CA of type C of resname SER, resid 981 and segid V and altLoc >, <Atom 29371: CA of type C of resname SER, resid 982 and segid V and altLoc >, <Atom 29382: CA of type C of resname LYS, resid 983 and segid V and altLoc >, ..., <Atom 31697: CA of type C of resname LYS, resid 1129 and segid V and altLoc >, <Atom 31719: CA of type C of resname THR, resid 1130 and segid V and altLoc >, <Atom 31735: CA of type C of resname PRO, resid 1131 and segid V and altLoc >]>
# (2501, 151, 3)
# (2501,)
# Number of training frames: 2501
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1334.217           3.892
# most representative frames for /scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/6: [(0, 207, 1555.7218073220754)]
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 31545
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 2: H1 of type H of resname ASP, resid 1 and segid A1 and altLoc >, <Atom 3: H2 of type H of resname ASP, resid 1 and segid A1 and altLoc >, ..., <Atom 31743: C of type C of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31744: OT1 of type O of resname PRO, resid 1131 and segid V and altLoc >, <Atom 31745: OT2 of type O of resname PRO, resid 1131 and segid V and altLoc >]>
# 1.0
# 9716665383834518.0
# ...Analyzing ['/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/holo/fes/actin_holoVinc_opes_pullProj_free_gpu_pn_-20.0/7/7_fes_pullVt.full.xtc']
# Number of atoms in trajectory: 293509
# Number of frames in trajectory: 2501
# Number of atoms in selection: 151
# <AtomGroup [<Atom 29360: CA of type C of resname SER, resid 981 and segid V and altLoc >, <Atom 29371: CA of type C of resname SER, resid 982 and segid V and altLoc >, <Atom 29382: CA of type C of resname LYS, resid 983 and segid V and altLoc >, ..., <Atom 31697: CA of type C of resname LYS, resid 1129 and segid V and altLoc >, <Atom 31719: CA of type C of resname THR, resid 1130 and segid V and altLoc >, <Atom 31735: CA of type C of resname PRO, resid 1131 and segid V and altLoc >]>

# %%
#example bias trj
example_trj="/scratch/projects/hockygroup-archive/wpc252/projects/factin_vinculin/apo/fes/actin_apoVinc_FES_pullProj_highE_pn_0.0/26/26_fes_pullVt.run.50000000.xtc"
example_gro=example_trj.replace(".xtc",".gro")
example_biased_CA_trj = load_trajectory(example_trj, example_gro, apo_residues)
opes_out_file=glob(os.path.join(os.path.dirname(example_trj),"*.opes.out"))[0]
# Out:
# Number of atoms in trajectory: 235307
# Number of frames in trajectory: 2001
# Number of atoms in selection: 180
# <AtomGroup [<Atom 29360: CA of type C of resname ASP, resid 882 and segid SYSTEM>, <Atom 29372: CA of type C of resname GLU, resid 883 and segid SYSTEM>, <Atom 29387: CA of type C of resname GLU, resid 884 and segid SYSTEM>, ..., <Atom 32148: CA of type C of resname VAL, resid 1059 and segid SYSTEM>, <Atom 32164: CA of type C of resname ARG, resid 1060 and segid SYSTEM>, <Atom 32188: CA of type C of resname LYS, resid 1061 and segid SYSTEM>]>
# [0.       0.       0.       ... 8.299064 7.39794  6.510049]
# (50001,)

# %%
#bias_trj = 
print(bias_trj)
print(bias_trj.shape)
# Out:
# [ 0.       14.897801 22.935641 ...  5.981277  3.13292   6.510049]
# (2001,)

# %%
example_sgmm_metaD_weights_1cluster = scripts.sgmm_fit_with_attempts(example_biased_CA_trj, 1, 1, frame_weights, device=torch.device("cuda"))
rep_frame_list = get_representative_frames(example_sgmm_metaD_weights_1cluster, example_biased_CA_trj)
print(rep_frame_list)
# Out:
# Number of training frames: 2001
# Number of clusters: 1
# Number of attempts: 1
#  Attempt  Log Like per Frame    CPU Time (s)
# --------------------------------------------------
#        1            1565.988           2.573
# [(0, 191, 1822.5401490274614)]

# %%
#write representative frame
tmp = load_trajectory(example_trj, example_gro, atoms="", write_frame=10, write_prefix="example_biased_apo_snap")
# Out:
# Number of atoms in trajectory: 235307
# Number of frames in trajectory: 2001
# Number of atoms in selection: 32008
# <AtomGroup [<Atom 1: N of type N of resname ASP, resid 1 and segid SYSTEM>, <Atom 2: H1 of type H of resname ASP, resid 1 and segid SYSTEM>, <Atom 3: H2 of type H of resname ASP, resid 1 and segid SYSTEM>, ..., <Atom 32206: C of type C of resname LYS, resid 1061 and segid SYSTEM>, <Atom 32207: OT1 of type O of resname LYS, resid 1061 and segid SYSTEM>, <Atom 32208: OT2 of type O of resname LYS, resid 1061 and segid SYSTEM>]>

# %%
get_frame_catdcd("test_out_clust0",example_trj,example_gro,rep_frame_list[0][1])
# Out:
# /share/apps/vmd/1.9.3/lib/vmd/plugins/LINUXAMD64/bin/catdcd5.1/catdcd: error while loading shared libraries: libexpat.so.0: cannot open shared object file: No such file or directory

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 full_biased_trj[191].write("test.pdb")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'write'

# %%
# do cluster scan for apo eq
# uniform weights
cluster_array = np.arange(1,4,1)
train, cv = scripts.cross_validate_cluster_scan(apo_trj, 2500, covar_type="kronecker", cluster_array = cluster_array, n_training_sets=3, n_attempts = 5, dtype=torch.float32, device=torch.device("cuda"))
# shapeGMMTorch plots has a built-in plot function for this type of plot
from shapeGMMTorch import plots
# also need to load matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# create figure
fig, ax = plt.subplots(1,2,figsize=(8,4), dpi= 120, facecolor='w', edgecolor='k',sharex=True,sharey=True)
# Uniform Weights
ax[0].set_title("Uniform",fontsize=12)
plots.plot_log_likelihood_with_dd(ax[0],cluster_array,train,cv,fontsize=12,ylabel1=True,ylabel2=False,xlabel=True)
plt.show()
